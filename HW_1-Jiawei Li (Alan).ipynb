# %% [markdown]
# # MAS DSE 200: Homework 1 - Python, NumPy, and Pillow
#
# #### Tasks:
#
# - Introduction to Python and NumPy.
#
# - Submission on Gradescope:
#   - Submit this Jupyter notebook to "Homework 1"
#
# #### Due date: Friday 10/19/2023 at 11:59 PM PST
#
# ---
#
# Remember: when in doubt, read the documentation first.
#
# Python - https://docs.python.org/3/
#
# NumPy - https://numpy.org/doc/stable/

# %% [markdown]
# ## Instructions
#
# * You don’t need to explain your approach (unless specified) so please be concise in your submission.
# * To obtain full marks for a question, both the answer and the code should be correct.
# * Completely wrong (or missing) code with correct answer will result in zero marks.
# * Please code the solution in the space provided.

# %% [markdown]
# ## Part 1 - Python basics

# %% [markdown]
# ### 1.  Write a program to swap a float and an int variable and print their data types to verify the swapping operation
#
# * Initialize 2 variables my_int = 5 , and my_float = 1.5
# * Swap these variables such that my_int now holds the value of my_float and vice versa
# * Verify this by printing their data types

# %%
# COMPLETE THE CELL BELOW

my_int = 5
my_float = 1.5

print ("Value of my_int = ", my_int)
print ("Data type of my_int = ", type(my_int))
print ("Value of my_float = ", my_float)
print ("Data type of my_float = ", type(my_float))

# Swap the variables
temp = my_int
my_int = my_float
my_float = temp
print ("Value of my_int = ", my_int)
print ("Data type of my_int = ", type(my_int))
print ("Value of my_float = ", my_float)
print ("Data type of my_float = ", type(my_float))
# Out:
# Value of my_int =  5
# Data type of my_int =  <class 'int'>
# Value of my_float =  1.5
# Data type of my_float =  <class 'float'>
# Value of my_int =  1.5
# Data type of my_int =  <class 'float'>
# Value of my_float =  5
# Data type of my_float =  <class 'int'>

# %% [markdown]
# ### 2. Write a Python Program to Calculate the area and perimeter of a circle of radius `r`
#
#  $area = \pi r^2$
#
#  $perimter = 2 \pi r$
#
#  Hint - Use `math.pi` to get the value of $\pi$

# %%
# COMPLETE THE CELL BELOW
import math

r=float(input('type your radius: '))
#pi=math.pi
#type(pi)
area = math.pi*r**2
perimeter = 2*math.pi*r

print('The length of the diagonal of the square is %0.2f' % area)
# Out:
# type your radius: 6
# The length of the diagonal of the square is 113.10

# %% [markdown]
# ### 3.1 Write a Python function to Check if a Number is divisible by 3
#
# * Complete the function block
# * Initialize a variable `num`
# * Pass the `num` variable to `is_divisible_by_3` function. Print if the number is divisible by 3
# * Hint - A number is divisible by 3 if the sum of the digits is divisible by 3. Implement this check

# %%
# COMPLETE CELL BELOW

def is_divisible_by_3(n):
    # Complete this function
    if n % 3== 0:
        return(print("input is divisible by 3"))
    else:
        return(print("input is not divisible by 3"))    
    
num = int(input("type a number: "))
is_divisible_by_3(num)
# Take input from user

# Check if the number is divisible by 3
#print()
# Out:
# type a number: 32
# input is not divisible by 3

# %% [markdown]
# ### 3.2. Write a Python function to Check if a Number is divisible by 2
#
# * Complete the function block
# * Initialize a variable `num`
# * Pass the `num` variable to `is_divisible_by_2` function. Print if the number is divisible by 2

# %%
# COMPLETE CELL BELOW

def is_divisible_by_2(n):
    # Complete this function
    if n % 2== 0:
        return(print("input is divisible by 2"))
    else:
        return(print("input is not divisible by 2"))
num = int(input("type a number: "))
is_divisible_by_2(num)

# Check if the number is divisible by 2
# Out:
# type a number: 10
# input is divisible by 2

# %% [markdown]
# ### 3.3. Write a Python function to Check if a Number is divisible by 6
#
# * Complete the function block
# * Initialize a variable `num`
# * Pass the `num` variable to `is_divisible_by_6` function. Print if the number is divisible by 6
# * Hint - A number is divisible by 6 if it is divisible by both 2 and 3. Use the previously defined functions to check for this.

# %%
# COMPLETE CELL BELOW

def is_divisible_by_6(n):
    # Complete this function
    if n % 6== 0:
        return(print("input is divisible by 6"))
    else:
        return(print("input is not divisible by 6"))
    
num = int(input("type a number: "))
is_divisible_by_6(num)


# Check if the number is divisible by 6
# Out:
# type a number: 6
# input is divisible by 6

# %% [markdown]
# ### 4. Write a Python Program to Check if a number has exactly 3 digits(no zeros allowed at the beginning)
#
# * Initialize a variable `num`
# * Check and print if the number has 3 digits(no zeros allowed at the beginning)

# %%
# COMPLETE THE CELL BELOW

num = int(input("input a number: ")) 
if num in range(100,1000):
    print("the number is:", num, "the number has 3 digits")
else:
    print("the number is:", num, "the number has more/less than 3 digits")
# Take input from user

# Check if the number has exactly 3 digits
# Out:
# input a number: 12
# the number is: 12 the number has more/less than 3 digits

# %% [markdown]
# ### 5. Write a Python Program to Check Whether a string is palindrome or not
#
# * Initialize a string
# * Lower case it to allow easy comparison - Use `my_str.lower()`
# * Check using if-else statements if the string is a palindrome
# * A palindrome is a string which is same read forward or backwards.
# * Alternatively, use the [`extended slice`](https://docs.python.org/3/whatsnew/2.3.html#extended-slices) syntax to reverse a string and check for palindrome

# %%
# COMPLETE CELL BELOW

#my_str = 'aIbohPhoBiA' 
# change this value for a different output
def palindrome(my_str):
    my_str=my_str.lower()
    for i in range(len(my_str)):
        if my_str[i]==my_str[-(i+1)]:
            return True
        else:
            return False
            
str_test=input("type a string: ")
print(palindrome(str_test))
# Out:
# type a string: bohPhoBiA
# False

# %% [markdown]
# ### 6.  Print numbers divisible by 5 between 4 and 30, inclusive
#
# * One optimization would be to only generate numbers that are multiples of 5

# %%
# COMPLETE THE CELL BELOW

limit = range(4,31)
for number in limit: # Complete the loop
    if number % 5==0:
        print(number)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30

# %% [markdown]
# ### 7. Write a Python Program to print the first n numbers of the Fibonacci series
#
# * Initialize a variable n that denotes the number of elements of the Fibonacci series to be computed
# * Use a loop to print the first n numbers of the Fibonacci series
# * Fibonacci series is a recursive series where the `n-th` number in the series is a sum of `n-1`th and `n-2`th element in the series, starting from 0 and 1

# %%
# COMPLETE CELL BELOW
def fibonacci(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fibonacci(n-1)+fibonacci(n-2)

# print the first 5 Fibonacci numbers
n = 5
for i in range(n):
    print(fibonacci(i))
# Out:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# ### 8. Write a Python Program that defines a function to Remove consonants From a String
#
# * You can initialize a string of your choice
# * Define the function
# * Use a for loop to remove consonants(any letter other than a,e,i,o,u)

# %%
# COMPLETE THE CELL BELOW

def removeConsonants(s): # Complete the function
    new_str=""
    for i in s:
        if i not in 'bcdfghjklmnpqrstvwxyzBCDFGHJKLMNPQRSTVWXYZ':
            new_str=new_str+i
    return new_str

my_str = "Hello, how are you?. I hope you are doing well."

print(removeConsonants(my_str))
# Out:
# eo, o ae ou?. I oe ou ae oi e.

# %% [markdown]
# ### 9. Define a function that takes two numbers as arguments and returns the sum of all numbers between the arguments passed (exclusive)
#
# * You can define a range of your choice
# * Define the function
# * Use a for loop to add numbers within the range(exclusive)
# * Hint - You can also use the formula $1 + 2 + ... + n = \frac{n(n + 1)}{n+1}$

# %%
# COMPLETE THE CELL BELOW

def sumRange(a, b): # Complete the function using a for loop and range
    sum=0
    for i in range(a+1, b):
        sum+=i
    return sum
a = 5
b = 10
total = sumRange(a, b)
print("Result is", total)
# Out:
# Result is 30

# %% [markdown]
# ### 10. Define a class named Triangle that can defines the methods `area` and `perimeter`
#
# * The class can be constructed by the length of the sides. Hint - As arguments of `__init__`
# * $area = \sqrt{(s(s-a)(s-b)(s-c)}$ where $s=\frac{(a+b+c)}{2}$ is the semi-perimeter
# * $perimeter = a +  b + c$
# * **Optional** - If there are repeated calls to the `area` and the `perimeter` functions, how would you optimize the code?

# %%
# COMPLETE CELL BELOW
import math

class Triangle:
    def __init__ (self, a, b, c): 
        self.a=a
        self.b=b
        self.c=c
        
    def perimeter(self):
        return self.a+self.b+self.c
    
    def area(self):
        s=(self.a+self.b+self.c)/2
        return math.sqrt(s*(s-self.a)*(s-self.b)*(s-self.c))
    

triangle = Triangle(6,8,10)
                
print("perimeter is:", triangle.perimeter())
print("area is:", triangle.area())
# Out:
# perimeter is: 24
# area is: 24.0

# %% [markdown]
# ## Part 2 - NumPy

# %%
import numpy as np

# %% [markdown]
# ### 11. Random array
#
# Generate an integer random numpy array, A, of shape (6,6) with elements from 12 to 22(inclusive). Print the generated random array. (Hint: Look at the documentation of `numpy.random.randint`)

# %%
A=np.random.randint(12,23, size=(6,6))
print(A)
# Out:
# [[22 16 18 14 21 16]
#  [19 12 21 18 14 12]
#  [20 19 20 14 19 16]
#  [21 18 22 12 18 22]
#  [21 20 16 14 18 13]
#  [19 20 18 17 12 20]]

# %% [markdown]
# ### 12. Transpose and inverse of the array `A`
#
# Print the transpose and inverse of A.

# %%
A_transpose=A.transpose()
A_inverse=np.linalg.inv(A)
print(A_transpose)
print(A_inverse)
# Out:
# [[22 19 20 21 21 19]
#  [16 12 19 18 20 20]
#  [18 21 20 22 16 18]
#  [14 18 14 12 14 17]
#  [21 14 19 18 18 12]
#  [16 12 16 22 13 20]]
# [[-0.05469697  0.09752953 -0.50233917  0.23393483  0.34896526 -0.09704454]
#  [-0.13208775 -0.04756413  0.11799949 -0.02081892  0.08038941  0.01045677]
#  [-0.18331293  0.08421607  0.08764054  0.10127338  0.02031027 -0.09859413]
#  [ 0.14197082 -0.0031465   0.14210094 -0.21749262 -0.1851819   0.13424061]
#  [ 0.17325242 -0.08465965  0.26697895 -0.16388983 -0.20807088  0.01413557]
#  [ 0.12440486 -0.06741307 -0.00062693 -0.0093626  -0.14793851  0.0978844 ]]

# %% [markdown]
# ### 13. Array slicing
# 1. Print the first 3 rows of A.

# %%
A[0:3, :]
# Out:
# array([[22, 16, 18, 14, 21, 16],
#        [19, 12, 21, 18, 14, 12],
#        [20, 19, 20, 14, 19, 16]])

# %% [markdown]
# 2. Print the first 3 columns of A.

# %%
A[:, 0:3]
# Out:
# array([[22, 16, 18],
#        [19, 12, 21],
#        [20, 19, 20],
#        [21, 18, 22],
#        [21, 20, 16],
#        [19, 20, 18]])

# %% [markdown]
# ### 14. Broadcasting
#
# Add this vector `B=[1,2,3,4,5,6]` to all the rows of `A`. (Hint: Use broadcasting)

# %%
B=np.array([[1,2,3,4,5,6]])
# print(A)
# print(B)
print(A+B)
# Out:
# [[23 18 21 18 26 22]
#  [20 14 24 22 19 18]
#  [21 21 23 18 24 22]
#  [22 20 25 16 23 28]
#  [22 22 19 18 23 19]
#  [20 22 21 21 17 26]]

# %% [markdown]
# ### 15. Reshaping
#
# Add this vector `B=[1,2,3,4,5,6]` to all the columns of `A`. (Hint: Use np.reshape and broadcasting)

# %%
# print(A)
# print(B.transpose())
print(A+B.transpose())
# Out:
# [[23 17 19 15 22 17]
#  [21 14 23 20 16 14]
#  [23 22 23 17 22 19]
#  [25 22 26 16 22 26]
#  [26 25 21 19 23 18]
#  [25 26 24 23 18 26]]

# %% [markdown]
# ## Part 3 - Pillow

# %% [markdown]
# ### 16. Flip Image using loops
#
# Add a color image of your choosing to the directory. Show the image within the notebook. Extract and show only the red (R of RGB) in one image, only the G in one image, and only B in another image.

# %%
from PIL import Image
img = Image.open('nba2k.jpg')
# img.show()
display(img)

def red(picture):
    (width, height)=picture.size
    for x in range(width):
        for y in range(height):
            (r, g, b)=picture.getpixel((x,y))
            picture.putpixel((x,y), (r,0,0))

def green(picture):
    (width, height)=picture.size
    for x in range(width):
        for y in range(height):
            (r, g, b)=picture.getpixel((x,y))
            picture.putpixel((x,y), (0,g,0))
            
def blue(picture):
    (width, height)=picture.size
    for x in range(width):
        for y in range(height):
            (r, g, b)=picture.getpixel((x,y))
            picture.putpixel((x,y), (0,0,b))
red(img)
#img.show()
display(img)

img = Image.open('nba2k.jpg')
green(img)
#img.show()
display(img)

img = Image.open('nba2k.jpg')
blue(img)
#img.show()
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>

# %% [markdown]
# ### 17. Flip Image using loops
#
# Use nested for loops to cycle through an image. Create and show an new image flipping the image left to right.

# %%
from PIL import Image
img = Image.open('nba2k.jpg')

# use transpose method flip left to right
flip_img = img.transpose(Image.FLIP_LEFT_RIGHT)
display(img)
display(flip_img)

# use loops
img = Image.open('nba2k.jpg')
display(img)

(width, height)=img.size
for y in range(height):
    for x in range(width):
        (r,g,b)=img.getpixel((x,y))
        newx=width-1-x
        flip_img.putpixel((newx,y), (r,g,b))            

display(flip_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>
# <PIL.Image.Image image mode=RGB size=297x170>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>
# <PIL.Image.Image image mode=RGB size=297x170>

# %% [markdown]
# ### 18. Filtering
#
# Add your own new image to the directory, create 3 new images using 3 different filters ([Pillow Filter Help](https://pillow.readthedocs.io/en/stable/reference/ImageFilter.html))

# %%
from PIL import Image
from PIL import ImageFilter
im = Image.open("nba2k.jpg")
 
# Boxblur radius=2
im1 = im.filter(ImageFilter.BoxBlur(2))
display(im1)

# GaussianBlur radius=2
im2 = im.filter(ImageFilter.GaussianBlur(2))
display(im2)

# Unsharp Mask filter
im3= im.filter(ImageFilter.UnsharpMask(radius=2, percent=200, threshold=5))
display(im3)
# Out:
# <PIL.Image.Image image mode=RGB size=297x170>
# <PIL.Image.Image image mode=RGB size=297x170>
# <PIL.Image.Image image mode=RGB size=297x170>

# %% [markdown]
# ## Part 4 - Explore Python Libraries

# %% [markdown]
# ### 19. Find 3 Python Libraries
#
# Using Markup, briefly overview 3 Python Libraries you found interesting. At least have 3 bullet points describing each Python Library. (Do not overview Numpy or Pillow)

# %% [markdown]
# <<<< Use this cell to write your response >>>>>
# #### 1. Pandas
# * Pandas library is built on top of the NumPy library, Pandas is widely used in data science and analysis for working with data sets
# * A fast and efficient DataFrame object for data manipulation with integrated indexing
# * Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format
# * Data alignment and integrated handling of missing data
# * Flexible reshaping and pivoting of data sets
#
# #### 2. Matplotlib
# * Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python
# * Create various types of graphs, including line plots, scatter plots, bar plots, histograms, pie charts, and more
# * Make interactive figures that can zoom, pan, update
# * Customize visual style and layout, allowing user to control colors, markers, legends, axis scales, and much more
# * Export to many file formats (e.g., PNG, PDF) and embed them in various graphical user interfaces or web applications
#
# #### 3. Beautiful Soup
# * Beautiful Soup is a library that makes it easy to scrape information from web pages
# * It sits atop an HTML or XML parser, providing Pythonic idioms for iterating, searching, and modifying the parse tree
# * It can be used to format and prettify the HTML or XML content, making it more human-readable

# %% [markdown]
# $\alpha^2$
